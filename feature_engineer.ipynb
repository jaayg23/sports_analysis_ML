# %%
import pandas as pd

# %%
df_matches = pd.read_csv('club_data.csv')
df_matches.head()
# Out:
#   fecha_partido     equipo_local equipo_visitante  goles_local  \
# 0    2023-01-01  Atlético Python    Cebollitas FC            2
# 1    2023-01-08       NumPy City  Atlético Python            1
# 2    2023-01-15    Cebollitas FC      Data United            1
# 3    2023-01-22  Atlético Python      Data United            2
# 4    2023-01-29      Data United    Cebollitas FC            5
#
#    goles_visitante  posesion_local (%)  posesion_visitante (%)  \
# 0                0                  54                      46
# 1                5                  60                      40
# 2                0                  55                      45
# 3                3                  57                      43
# 4                3                  52                      48
#
#    tiros_arco_local  tiros_arco_visitante       estadio
# 0                12                     6  Python Arena
# 1                12                     3    Estadio ML
# ...

# %%
df_matches['diferencia_goles'] = df_matches['goles_local'] - df_matches['goles_visitante']

df_matches[['goles_local', 'goles_visitante', 'diferencia_goles']].head()
# Out:
#    goles_local  goles_visitante  diferencia_goles
# 0            2                0                 2
# 1            1                5                -4
# 2            1                0                 1
# 3            2                3                -1
# 4            5                3                 2

# %%
df_matches['ratio_tiros_posesion_local'] = df_matches['tiros_arco_local'] / df_matches['posesion_local (%)']

df_matches[['tiros_arco_local', 'posesion_local (%)', 'ratio_tiros_posesion_local']].head()
# Out:
#    tiros_arco_local  posesion_local (%)  ratio_tiros_posesion_local
# 0                12                  54                    0.222222
# 1                12                  60                    0.200000
# 2                10                  55                    0.181818
# 3                 3                  57                    0.052632
# 4                 7                  52                    0.134615

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.histplot(df_matches['diferencia_goles'], bins=15, kde=True)
plt.title('Distribución de la diferencia de goles')
plt.xlabel('Diferencia de goles')
plt.ylabel('Frecuencia')
plt.show()

# %%
corr_vars = ['goles_local', 'goles_visitante', 'diferencia_goles', 'ratio_tiros_posesion_local']
corr_matrix = df_matches[corr_vars].corr()

sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Matriz de correlación')
plt.show()
